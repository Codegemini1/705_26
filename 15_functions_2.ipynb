# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
    print('#' * i)
# Out:
# #
# ##
# ###
# ####
# #####

# %%
def star_pattern(num):
    for i in range(1,num + 1):
        print('#' * i)

# %%
star_pattern(5)
# Out:
# #
# ##
# ###
# ####
# #####

# %%
# Reverse star pattern

# %%
# Sum till that number

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
total = 0
for i in range(1,6):
    total = total + i
    print(total)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
def total(num):
    total = 0
    for i in range(1,num +1):
        total = total + i
    print(total)

# %%
total(4)
# Out:
# 10

# %%
n = 10000
total = n * (n+1) / 2
total
# Out:
# 50005000.0

# %%
# maximum num

# %%
a = 5
b = 10
c = 1

# %%
if a > b and a > c:
    print(a, 'a')
elif b > a and b > c:
    print(b, 'b')
else:
    print(c, 'c')
# Out:
# 10 b

# %%
def greater(a,b,c):
    if a > b and a > c:
        print(a, 'a')
    elif b > a and b > c:
        print(b, 'b')
    else:
        print(c, 'c')

# %%
def total(num):
    addition = 0 # local variables
    for i in range(1,num +1):
        addition = addition + i
    print(addition)

# %%
total(5)
# Out:
# 15

# %%
addition
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 addition
#
# NameError: name 'addition' is not defined

# %%
a
# Out:
# 5

# %%
g = 80 # Global var

# %%
g
# Out:
# 80

# %%
greater(1,2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 greater(1,2,3,4,5,6)
#
# TypeError: greater() takes 3 positional arguments but 6 were given

# %%
# Multiple arguments *args

# %%
def summation(*args):
    print(args)

# %%
summation(1,2,4,12,45,23,44)
# Out:
# (1, 2, 4, 12, 45, 23, 44)

# %%
summation(1)
# Out:
# (1,)

# %%
def test1(*gemini):
    for i in gemini:
        print(i + 10)

# %%
test1(1,2,4,12,45,23,44)
# Out:
# 11
# 12
# 14
# 22
# 55
# 33
# 54

# %%
def total(num):
    total = 0
    for i in range(1,num +1):
        total = total + i
    print(total)

# %%
total(5)
# Out:
# 15

# %%
type(total(5))
# Out:
# 15
# NoneType

# %%
def total(num):
    total = 0
    for i in range(1,num +1):
        total = total + i
    return total

# %%
total(5)
# Out:
# 15

# %%
type(total(5))
# Out:
# int

# %%
def star_pattern(num):
    for i in range(1,num + 1):
        print('#' * i)

# %%
def new_star_pattern(num):
    for i in range(1,num + 1):
        pass
    return '#' * i

# %%
star_pattern(5)
# Out:
# #
# ##
# ###
# ####
# #####

# %%
new_star_pattern(5)
# Out:
# '#####'

# %%
def greater(a,b,c):
    if a > b and a > c:
        print(a, 'a')
    elif b > a and b > c:
        print(b, 'b')
    else:
        print(c, 'c')

# %%
def new_greater(a,b,c):
    if a > b and a > c:
        return a, 'a'
    elif b > a and b > c:
        return b, 'b'
    else:
        return c, 'c'

# %%
new_greater(10,20,5)
# Out:
# (20, 'b')

# %%
def new_sum(*args):
    total = 0
    for i in args:
        total = total + i
    return total

# %%
new_sum(91,34,22,3,6,23,53,12)
# Out:
# 244

# %%
def test2(a,b,*args):
    return a, b, args

# %%
test2(10,20,30,40,50,60)
# Out:
# (10, 20, (30, 40, 50, 60))

# %%
len()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 test2()
#
# TypeError: test2() missing 2 required positional arguments: 'a' and 'b'

# %%
def test3(a,b):
    """This test3 function will add a and b.
    It will take only 2 argument."""

    return a + b

# %%
test3(10,2)
# Out:
# 12

# %%
def test4(*args, a,b):
    #  error
# Out:
#   Cell In[66], line 2
#     #  error
#             ^
# SyntaxError: incomplete input

# %%
# Filter out int type of data from multiple args,

# %%
def test5(*args):
    l = []
    for i in args:
        if type(i) == int:
            l.append(i)
    return l

# %%
test5(1,1.5,True, 13, 1+5j)
# Out:
# [1, 13]

# %% [raw]
# # Filter out list type of data from multiple args --> print out that list data
# (1,[10,,20,30], (1,2,3), {'a':2, 'b':3})
# # find out int type of data from given arguments
# (1,1.5,[10,20,'Hello'],100,True)
