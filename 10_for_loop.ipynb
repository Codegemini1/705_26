# %% [markdown]
# # Obj should be iterable

# %%
l= [1,2,3,4,5]

# %%
for number in l:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
for number in l:
    print(number + 10)
# Out:
# 11
# 12
# 13
# 14
# 15

# %%
for data in l:
    print(data)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for data in l:
    print(data,type(data))
# Out:
# 1 <class 'int'>
# 2 <class 'int'>
# 3 <class 'int'>
# 4 <class 'int'>
# 5 <class 'int'>

# %%
for data in l:
    print('Hello')
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
for i in 'python':
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
names = ['Rock', 'John', 'Alex', 'Siya']

# %%
for i in names:
    print(i)
# Out:
# Rock
# John
# Alex
# Siya

# %%
for i in names:
    print(f'My name is {i}')
# Out:
# My name is Rock
# My name is John
# My name is Alex
# My name is Siya

# %%
mix = [10, 1.5, 'Python', True, 10+5j]

# %%
for i in mix:
    print(i)
# Out:
# 10
# 1.5
# Python
# True
# (10+5j)

# %%
for i in mix:
    print(f'Obj is {i} and its data type is {type(i)}')
# Out:
# Obj is 10 and its data type is <class 'int'>
# Obj is 1.5 and its data type is <class 'float'>
# Obj is Python and its data type is <class 'str'>
# Obj is True and its data type is <class 'bool'>
# Obj is (10+5j) and its data type is <class 'complex'>

# %%
# How to iterate a nested list

# %%
l = [10,20,30,[1,2,3],40]

# %%
for object in l:
    print(object)
# Out:
# 10
# 20
# 30
# [1, 2, 3]
# 40

# %%
for object in l:
    print(object, type(object))
# Out:
# 10 <class 'int'>
# 20 <class 'int'>
# 30 <class 'int'>
# [1, 2, 3] <class 'list'>
# 40 <class 'int'>

# %%
for object in l:
    if type(object)

# %%
if type(5) == int:
    print('Yes data type is int')
else:
    print('Not int data type')

# %%
type(5)
# Out:
# int

# %%
int == int
# Out:
# True

# %%
if type('Hello') == int:
    print('Yes data type is int')
else:
    print('Not int data type')
# Out:
# Not int data type

# %%
l
# Out:
# [10, 20, 30, [1, 2, 3], 40]

# %%
for object in l:
    if type(object) == list:
        print(object)
# Out:
# [1, 2, 3]

# %%
int == list
# Out:
# False

# %%
type([1,2,3])
# Out:
# list

# %%
list == list
# Out:
# True

# %%
mix
# Out:
# [10, 1.5, 'Python', True, (10+5j)]

# %%
for object in mix:
    if type(object) == int:
        print(object)

# %%
for object in mix:
    if type(object) == str:
        print(object)
# Out:
# Python

# %%
l
# Out:
# [10, 20, 30, [1, 2, 3], 40]

# %%
for object in l:
    if type(object) == list:
        for i in object:
            print(i)
# Out:
# 1
# 2
# 3

# %%
for object in l:
    if type(object) == list:
        for i in object:
            print(object)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
names
# Out:
# ['Rock', 'John', 'Alex', 'Siya']

# %%
for i in names:
    print(i)
# Out:
# Rock
# John
# Alex
# Siya

# %%
for i in names:
    if type(i) == str:
        for char in i:
            print(char)
# Out:
# R
# o
# c
# k
# J
# o
# h
# n
# A
# l
# e
# x
# S
# i
# y
# a

# %%
o = []
for i in names:
    if type(i) == str:
        for char in i:
            o.append(char)

# %%
o
# Out:
# ['R',
#  'o',
#  'c',
#  'k',
#  'J',
#  'o',
#  'h',
#  'n',
#  'A',
#  'l',
#  'e',
#  'x',
#  'S',
#  'i',
#  'y',
#  'a']
