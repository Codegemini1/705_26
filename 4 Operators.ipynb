# %% [markdown]
# # Assignment Operator

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a += 1 # a = a + 1

# %%
a
# Out:
# 6

# %%
b = 10

# %%
b -= 5# b = b - 5

# %%
b
# Out:
# 5

# %%
c = 10

# %%
c *= 5 # c = c * 5

# %%
c
# Out:
# 50

# %%
d = 15

# %%
d /= 3 # d = d / 3

# %%
d
# Out:
# 5.0

# %%
e = 10

# %%
e %= 2# e = e % 2

# %%
e
# Out:
# 0

# %%
f = 2

# %%
f **= 3 # f = f ** 3

# %%
f
# Out:
# 8

# %%
j = 15

# %%
j //= 2 # j = j // 2

# %%
j
# Out:
# 7

# %%
15 / 2
# Out:
# 7.5

# %% [markdown]
# # Comparison Operators / Relational

# %%
5 == 5
# Out:
# True

# %%
10 == 5
# Out:
# False

# %%
'h' == 'h'
# Out:
# True

# %%
'h' == 'z'
# Out:
# False

# %%
'hello' == 'hello'
# Out:
# True

# %%
'A' == 'a'
# Out:
# False

# %%
5 != 5
# Out:
# False

# %%
10 != 5
# Out:
# True

# %%
'hello' != 'python'
# Out:
# True

# %%
'exit' != 'exit'
# Out:
# False

# %%
5 > 10
# Out:
# False

# %%
10 > 5
# Out:
# True

# %%
1 < 0
# Out:
# False

# %%
0 < 1
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 <= 5
# Out:
# True

# %%
10 >= 5
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
True and True
# Out:
# True

# %%
# All Truth table of and , or

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # Membership Operators

# %%
'i' in 'hindi'
# Out:
# True

# %%
'i' not in 'hindi'
# Out:
# False

# %%
# Write down minimum 10 examples of each operators
