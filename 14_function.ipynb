# %%
def test1():
    print('Hello AI world')

# %%
test1()
# Out:
# Hello AI world

# %%
test1()
# Out:
# Hello AI world

# %%
def test2(f):
    print(f)

# %%
test2(10)
# Out:
# 10

# %%
test2('Hello AI')
# Out:
# Hello AI

# %%
def test3(a,b):
    print(a + b)

# %%
test3(10,5)
# Out:
# 15

# %%
# Write a funcction for square of number
def square(a):
    print(a * a)

# %%
square(3)
# Out:
# 9

# %%
square(2)
# Out:
# 4

# %%
square(1342)
# Out:
# 1800964

# %%
def even_odd(num):
    if num % 2 == 0:
        print('Even number')
    else:
        print('Odd number')

# %%
even_odd(628)
# Out:
# Even number

# %%
even_odd(23)
# Out:
# Odd number

# %%
# Multiplication
# Sub
# ADD
# Div
