# %% [markdown]
# # Slicing

# %%
l = [20,15,25,50,30,70]

# %%
l[0:3]
# Out:
# [20, 15, 25]

# %%
l[1:4]
# Out:
# [15, 25, 50]

# %%
l[2:6]
# Out:
# [25, 50, 30, 70]

# %%
l[2:]  # empty colun is considered as till end of list
# Out:
# [25, 50, 30, 70]

# %%
l[:]
# Out:
# [20, 15, 25, 50, 30, 70]

# %%
l[3:]
# Out:
# [50, 30, 70]

# %%
l[:3]
# Out:
# [20, 15, 25]

# %%
z = [10,20,50,76,89,56,87,90]

# %%
z
# Out:
# [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[:]
# Out:
# [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[::-1]
# Out:
# [90, 87, 56, 89, 76, 50, 20, 10]

# %%
z
# Out:
# [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3:1:-1]
# Out:
# [56, 89, 76, 50]

# %%
z[5:1:-1]
# Out:
# [56, 89, 76, 50]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %%
z[::-2]
# Out:
# [90, 56, 76, 20]

# %% [markdown]
# # Try on nested lists also
