# %%
first_name = 'Sham' #str
last_name = 'Kumar' #str

# %%
print(first_name + last_name)
# Out:
# ShamKumar

# %%
print(first_name + ' ' + last_name)
# Out:
# Sham Kumar

# %%
marks = 58

# %%
print(first_name + marks) # str + int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Combine unique datasets we can use ','
# ----> 2 print(first_name + marks)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Combine unique datasets we can use ','
print(first_name , marks)  #not cocatinating
# Out:
# Sham 58

# %%
print('My name is ' + first_name)
# Out:
# My name is Sham

# %%
print('My name is ' + first_name + 'I got above marks:- ', marks)
# Out:
# My name is ShamI got above marks:-  58

# %%
first_name
# Out:
# 'Sham'

# %%
# f formating 
print(f'My name is {first_name} and I got {marks} marks')
# Out:
# My name is Sham and I got 58 marks

# %%
profession = 'Software Engineer'
work = 'Write Code'
salery = 70000

# %%
print(f'My prefession is {profession} and my work is to {work} and I am getting {salery} in hand')
# Out:
# My prefession is Software Engineer and my work is to Write Code and I am getting 70000 in hand

# %%
# How to take user input
name = input('Write your full name')
print(f'Your full name is {name}')
# Out:
# Write your full name Sham Hira Kumar
# Your full name is Sham Hira Kumar

# %%
first_name = input()
last_name = input('Write your last name')
print(first_name + last_name)
# Out:
#  Om
# Write your last name Kumar
# OmKumar

# %%
type(first_name)
# Out:
# str

# %%
type(last_name)
# Out:
# str

# %%
# What if I have to take int input
age = input('Write your age')
print('Your age is' + age)
# Out:
# Write your age 40
# Your age is40

# %%
type(age)
# Out:
# str

# %%
'40'
# Out:
# '40'

# %%
type('40')
# Out:
# str

# %%
int('40')
# Out:
# 40

# %%
age = int(input('Write your age'))
# Out:
# Write your age 40

# %%
age
# Out:
# 40

# %%
type(age)
# Out:
# int

# %%
height = int(input('Write height'))  #int
# Out:
# Write height 7.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 height = int(input('Write height'))
#
# ValueError: invalid literal for int() with base 10: '7.2'

# %%
profession = input('Enter your profession')  #str 
work = input('Enter your work in detail')    #str
salery = int(input('Enter your salery in numbers only')) #int
print(f'Your profession is {profession}. Your work is to {work}. Your salery is {salery}. ')
# Out:
# Enter your profession Civil Engineer
# Enter your work in detail build buildings
# Enter your salery in numbers only 30000
# Your profession is Civil Engineer. Your work is to build buildings. Your salery is 30000.

# %%
# You can take similar input for float 
height = float(input('Enter your height in feet'))
print(f'Your Height is {height} in feet')
# Out:
# Enter your height in feet 7.3
# Your Height is 7.3 in feet

# %%
# Multiple variables

# %%
a,b,c = 10,20,30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %% [markdown]
# # Arithmetic Operators

# %%
'+'
# Out:
# '+'

# %%
10 + 5
# Out:
# 15

# %%
'Hello' + 'World'
# Out:
# 'HelloWorld'

# %%
10 - 5
# Out:
# 5

# %%
4 -1.23
# Out:
# 2.77

# %%
10 * 5
# Out:
# 50

# %%
2 * 7
# Out:
# 14

# %%
'Hello' * 3
# Out:
# 'HelloHelloHello'

# %%
'O' * 10
# Out:
# 'OOOOOOOOOO'

# %%
'_' * 80
# Out:
# '________________________________________________________________________________'

# %%
10 / 5
# Out:
# 2.0

# %%
3 / 2
# Out:
# 1.5

# %%
787 / 7
# Out:
# 112.42857142857143

# %%
10 %  3
# Out:
# 1

# %%
10 % 2  # rem will be 0 ---> even numbers
# Out:
# 0

# %%
13 % 2 #odd number
# Out:
# 1

# %%
173673 % 213
# Out:
# 78

# %%
# Power

# %%
2 ** 3
# Out:
# 8

# %%
3 ** 2
# Out:
# 9

# %%
x = 70
print( x ** 2)
