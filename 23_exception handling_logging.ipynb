# %%
try:
    num = int(input('Number'))
    result = 10/num
except ValueError:
    print('Invalid input')
except ZeroDivisionError:
    print('Cannot devide by zero')
# Out:
# Number 1.5
# Invalid input

# %%
num = int(input('Number'))
# Out:
# Number 1.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num = int(input('Number'))
#
# ValueError: invalid literal for int() with base 10: '1.4'

# %%
# Else
try:
    num = int(input('Enter a num'))
except ValueError: #if 
    print('Invalid input')
else:
    print('You have entered', num)
# Out:
# Enter a num 1.5
# Invalid input

# %%
# finally
try:
    open('file.txt') #default uses read mode
except FileNotFoundError:
    print('File not found')
finally:
    print('Code completed')
# Out:
# File not found
# Code completed

# %%
try:
    password = input('Enter password')
    if password != 'admin':
        raise ValueError('Wrong password')
except ValueError as e:
    print(e)
# Out:
# Enter password True
# Wrong password

# %%
password = input('Enter password')
if password != 'admin':
    print('Wrong password')
else:
    print('Logged in')

# %%
try:
    f = open('intro.txt')
    print(f.read())
except FileNotFoundError:
    print('File not found ')
# Out:
# Welcome to the world of AIve did may batchelors in xyz field.This is my updated introThis is my new text

# %%
data = ['10','20','30','abc','40']

# %%
data
# Out:
# ['10', '20', '30', 'abc', '40']

# %%
for i in data:
    print(i, type(i))
# Out:
# 10 <class 'str'>
# 20 <class 'str'>
# 30 <class 'str'>
# abc <class 'str'>
# 40 <class 'str'>

# %%
int('abc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int('abc')
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
data
# Out:
# ['10', '20', '30', 'abc', '40']

# %%
for i in data:
    try:
        num = int(i)
        print(num, type(num))
    except ValueError:
        print('Invalid data type to conv into int', i)
# Out:
# 10 <class 'int'>
# 20 <class 'int'>
# 30 <class 'int'>
# Invalid data type to conv into int abc
# 40 <class 'int'>

# %%
# Custom error raising
def check_age(age):
    if age < 18:
        raise Exception ('Not valid age for driving car')
    print('Valid age for driving car', age)

# %%
check_age(10)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 check_age(10)
#
# Cell In[21], line 4, in check_age(age)
#       2 def check_age(age):
#       3     if age < 18:
# ----> 4         raise Exception ('Not valid age for driving car')
#       5     print('Valid age for driving car', age)
#
# Exception: Not valid age for driving car

# %%
class Myerror(Exception):
    pass
raise Myerror('Cutom error happened')
# Out:
# ---------------------------------------------------------------------------
# Myerror                                   Traceback (most recent call last)
# Cell In[23], line 3
#       1 class Myerror(Exception):
#       2     pass
# ----> 3 raise Myerror('Cutom error happened')
#
# Myerror: Cutom error happened

# %% [markdown]
# # logging

# %%
import logging

# %%
logging.basicConfig(level = logging.INFO)
logging.info('Project strated')
# Out:
# INFO:root:Project strated

# %% [raw]
# DEBUG -- > Detailed info
# INFO ----> Simple info
# WARNING ---> Something unexpected
# ERROR ---> issue
# CRITICAL ---> Sysytem failure

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

logging.debug('DEBUG logging')
logging.info('Info logging')
logging.warning('Warning logging')
logging.error('Error logging')
logging.critical('Critical logging')
# Out:
# INFO:root:Info logging
# WARNING:root:Warning logging
# ERROR:root:Error logging
# CRITICAL:root:Critical logging

# %%
import logging
logging.basicConfig(level=logging.ERROR)

try:
    x = 10/0
except ZeroDivisionError:
    logging.error('Cannot devide by zero')
# Out:
# ERROR:root:Cannot devide by zero

# %%
import logging
logging.basicConfig(level=logging.ERROR)

try:
    x = 10/0
except Exception as e:
    logging.error('Error happened: %s', e)
# Out:
# ERROR:root:Error happened: division by zero

# %%
import logging 
logging.basicConfig(filename='app.log', level=logging.INFO)

logging.info('Project started')
try:
    x = 10/0
except Exception as e:
    logging.error('Error happened: %s', e)
# Out:
# INFO:root:Project started
# ERROR:root:Error happened: division by zero

# %%
logging.shutdown()

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B608-DCBC
#
#  Directory of C:\Users\bhosa\Downloads\705\Advaned_python
#
# 02-04-2026  12:16    <DIR>          .
# 02-04-2026  12:16    <DIR>          ..
# 02-04-2026  11:14    <DIR>          .ipynb_checkpoints
# 31-03-2026  11:41    <DIR>          __pycache__
# 26-03-2026  12:16            13,000 18_oop_1.ipynb
# 26-03-2026  12:25            19,203 18_oop_1_practice.docx
# 27-03-2026  12:27            17,517 19_OOP_2.ipynb
# 27-03-2026  12:32            18,533 19_oop_2_practice.docx
# 30-03-2026  12:10            18,276 20_file_h_questions.docx
# 30-03-2026  12:05            39,497 20_file_handling.ipynb
# 31-03-2026  11:21             1,633 21_1_modules.ipynb
# 31-03-2026  11:41             4,634 21_2_modules.ipynb
# 31-03-2026  12:20            10,059 22_exception_handling.ipynb
# 02-04-2026  12:16            14,405 23_exception handling.ipynb
# 30-03-2026  11:35               769 Agentic_ai.txt
# 30-03-2026  12:00                65 base.py
# 31-03-2026  11:28               248 imp_functions.py
# 30-03-2026  11:57               104 intro.txt
# 31-03-2026  11:22                 0 New Text Document.txt
# 31-03-2026  11:41               148 project.py
#               16 File(s)        158,091 bytes
#                4 Dir(s)  17,060,397,056 bytes free

# %%
import logging 
logging.basicConfig(filename='new.log', level=logging.INFO, 
                    format="%(asctime)s - %(levelname)s - %(message)s")

logging.info('Project started')
try:
    x = 10/0
except Exception as e:
    logging.error('Error happened: %s', e)
# Out:
# INFO:root:Project started
# ERROR:root:Error happened: division by zero
