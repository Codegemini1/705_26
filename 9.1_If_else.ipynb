# %%
tasks = []
time = int(input('Write your current time'))
cloths = input('Tell me your cloths are dirty or clean')
date = int(input('Write only date 15,01'))
if time > 10:
    tasks.append('I have to buy Milk')
elif cloths == 'dirty':
    tasks.append('Pikup cloths for cleaning')
elif date >= 15:
    tasks.append('Pay rent 15th dat is complted')
# Out:
# Write your current time 18
# Tell me your cloths are dirty or clean clean
# Write only date 15,01 12

# %%
tasks
# Out:
# ['I have to buy Milk']

# %%
tasks = []
cloths = input('Tell me your cloths are dirty or clean')
date = int(input('Write only date 15,01'))
time = int(input('Write your current time'))

if time > 10:
    tasks.append('I have to buy Milk')
    print('I have to buy Milk')
else:
    print('Milk is not required')

if cloths == 'dirty':
    tasks.append('Pikup cloths for cleaning')
    print('Pikup cloths for cleaning')
else:
    print('No need to clean')
if date >= 15:
    tasks.append('Pay rent 15th dat is complted')
    print('Pay rent 15th date is over or going')
else:
    print('No need to pay rent')
# Out:
# Tell me your cloths are dirty or clean dirty
# Write only date 15,01 12
# Write your current time 18
# I have to buy Milk
# Pikup cloths for cleaning
# No need to pay rent

# %%
tasks
# Out:
# ['I have to buy Milk', 'Pikup cloths for cleaning']

# %%
# bank loan approval
salary = int(input('Please enter your salary'))
credit_score = int(input('Enter your credit score between 0 - 900'))

if salary > 30000 and credit_score > 700:
    print('You can get loan easily')
else:
    print('Loan rejected')
# Out:
# Please enter your salary 48000
# Enter your credit score between 0 - 900 850
# You can get loan easily
