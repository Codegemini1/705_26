# %%
class car():
    def __init__(self,body_type,fuel,color,engine): # CONSTRUCTOR
        self.body_type = body_type
        self.fuel = fuel
        self.color = color
        self.engine = engine

# %%
swift = car('suv', 'petrol', 'red', 1200)

# %%
swift.body_type
# Out:
# 'suv'

# %%
swift.color
# Out:
# 'red'

# %%
swift.engine
# Out:
# 1200

# %%
swift.fuel
# Out:
# 'petrol'

# %%
class house():
    def __init__(self,name,floors,size,lift):
        self.name = name
        self.floors = floors
        self.size = size
        self.lift = lift

# %%
object1 = house('Mannat', 5, 5000, 'Yes')

# %%
object1.name
# Out:
# 'Mannat'

# %%
object1.lift
# Out:
# 'Yes'

# %%
object1.size
# Out:
# 5000

# %%
object1.floors
# Out:
# 5

# %%
class student():
    def __init__(self, name, age, roll_num):
        self.name = name
        self.age = age
        self.roll_num = roll_num

    def display(self):
        print(f'Students name is: {self.name} her/his age is:  {self.age} and roll number is  {self.roll_num}')

# %%
s1 = student('Vaibhav', 25, 41)

# %%
s1.display()
# Out:
# Students name is: Vaibhav her/his age is:  25 and roll number is  41

# %%
class car():
    def __init__(self,body_type,fuel,color,engine): # CONSTRUCTOR
        self.body_type = body_type
        self.fuel = fuel
        self.color = color
        self.engine = engine
    def start(self):
        return 'Car is started'
    def stop(self):
        return 'Car is stopped'
    def open_sunroof(self):
        return 'Sunroof is opning'

# %%
fortuner = car('SUV', 'Diesel', 'White',2000 )

# %%
fortuner.start()
# Out:
# 'Car is started'

# %%
fortuner.open_sunroof()
# Out:
# 'Sunroof is opning'

# %%
fortuner.stop()
# Out:
# 'Car is stopped'

# %%
class laptop():
    def display(self):
        return ' This laptop is having 60hz display'

# %%
hp = laptop()

# %%
hp.display()
# Out:
# ' This laptop is having 60hz display'

# %%
# 10 diff types of classes with features

# %% [markdown]
# # Encapsulation

# %%
class bank_account():
    def __init__(self, balance):
        self.__balance = balance #Private

# %%
obj2 = bank_account(1000)

# %%
obj2._bank_account__balance #_classname__variblename
# Out:
# 1000

# %%
class bank_account():
    def __init__(self, balance):
        self.__# balance = balance #Private
    def deposite(self,amount):
        self.__balance = self.__balance + amount
    def balance_check(self):
        return self.__balance

# %%
obj3 = bank_account(100)

# %%
obj3.balance_check()
# Out:
# 100

# %%
obj3.deposite(50)

# %%
obj3.balance_check()
# Out:
# 150

# %%
class mobile():
    def __init__(self,amount,offer,color):
        self.__amount = amount # private
        self._offer = offer    #protected
        self.color = color     # public

# %%
m1 = mobile(1000,50,'red')

# %%
m1.color
# Out:
# 'red'

# %%
m1._offer
# Out:
# 50

# %%
m1._mobile__amount
# Out:
# 1000
