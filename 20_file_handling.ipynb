# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B608-DCBC
#
#  Directory of C:\Users\bhosa\Downloads\705\Advaned_python
#
# 30-03-2026  11:16    <DIR>          .
# 30-03-2026  11:16    <DIR>          ..
# 30-03-2026  11:16    <DIR>          .ipynb_checkpoints
# 26-03-2026  12:16            13,000 18_oop_1.ipynb
# 26-03-2026  12:25            19,203 18_oop_1_practice.docx
# 27-03-2026  12:27            17,517 19_OOP_2.ipynb
# 27-03-2026  12:32            18,533 19_oop_2_practice.docx
# 30-03-2026  11:16               337 Untitled.ipynb
#                5 File(s)         68,590 bytes
#                3 Dir(s)  44,658,659,328 bytes free

# %%
f = open('intro.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 f = open('intro.txt', 'r')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'intro.txt'

# %%
f = open('intro.txt', 'w')

# %%
f.write("Hello my name is xyz. I have did may batchelors in xyz field.")
# Out:
# 61

# %%
f.close()

# %%
f= open('intro.txt', 'r')

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.'

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.'

# %%
f.seek(4)
# Out:
# 4

# %%
f.read()
# Out:
# 'o my name is xyz. I have did may batchelors in xyz field.'

# %%
f.seek(7)
# Out:
# 7

# %%
f.read()
# Out:
# 'y name is xyz. I have did may batchelors in xyz field.'

# %%
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 f.write('hello')
#
# UnsupportedOperation: not writable

# %%
f.close()

# %%
f = open('intro.txt', 'r+') # both permissions for read and write

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.'

# %%
f.write('This is my updated intro')
# Out:
# 24

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.This is my updated intro'

# %%
f.close()

# %%
f= open('Agentic_ai.txt', 'w')

# %%
f.write("""Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action. While traditional AI is reactive and follows fixed rules, Agentic AI is proactive and can accomplish complex goals with minimal human intervention. 
IBM
IBM
 +2
Key Characteristics
Autonomy: Operates independently without needing step-by-step human guidance.
Goal-Orientation: Reasons through high-level objectives, breaking them down into multi-step plans.
Adaptability: Uses feedback and memory to self-correct and adjust strategies in real-time if a task fails or conditions change.
Tool Usage: Connects directly with external systems like APIs, databases, and software to execute work (e.g., sending emails or updating a CRM)""")
# Out:
# 761

# %%
f.close()

# %%
f = open('Agentic_ai.txt', 'r+') # We have multiple lines

# %%
f.read()
# Out:
# 'Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action. While traditional AI is reactive and follows fixed rules, Agentic AI is proactive and can accomplish complex goals with minimal human intervention. \nIBM\nIBM\n +2\nKey Characteristics\nAutonomy: Operates independently without needing step-by-step human guidance.\nGoal-Orientation: Reasons through high-level objectives, breaking them down into multi-step plans.\nAdaptability: Uses feedback and memory to self-correct and adjust strategies in real-time if a task fails or conditions change.\nTool Usage: Connects directly with external systems like APIs, databases, and software to execute work (e.g., sending emails or updating a CRM)'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action. While traditional AI is reactive and follows fixed rules, Agentic AI is proactive and can accomplish complex goals with minimal human intervention. \n'

# %%
f.readline()
# Out:
# 'IBM\n'

# %%
f.readline()
# Out:
# 'IBM\n'

# %%
f.readline()
# Out:
# ' +2\n'

# %%
f.readline()
# Out:
# 'Key Characteristics\n'

# %%
f.readline()
# Out:
# 'Autonomy: Operates independently without needing step-by-step human guidance.\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action. While traditional AI is reactive and follows fixed rules, Agentic AI is proactive and can accomplish complex goals with minimal human intervention. \n',
#  'IBM\n',
#  'IBM\n',
#  ' +2\n',
#  'Key Characteristics\n',
#  'Autonomy: Operates independently without needing step-by-step human guidance.\n',
#  'Goal-Orientation: Reasons through high-level objectives, breaking them down into multi-step plans.\n',
#  'Adaptability: Uses feedback and memory to self-correct and adjust strategies in real-time if a task fails or conditions change.\n',
#  'Tool Usage: Connects directly with external systems like APIs, databases, and software to execute work (e.g., sending emails or updating a CRM)']

# %%
f.seek(0)
# Out:
# 0

# %%
for line in f.readlines():
    print(line)
# Out:
# Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action. While traditional AI is reactive and follows fixed rules, Agentic AI is proactive and can accomplish complex goals with minimal human intervention.
#
# IBM
#
# IBM
#
#  +2
#
# Key Characteristics
#
# Autonomy: Operates independently without needing step-by-step human guidance.
#
# Goal-Orientation: Reasons through high-level objectives, breaking them down into multi-step plans.
#
# Adaptability: Uses feedback and memory to self-correct and adjust strategies in real-time if a task fails or conditions change.
#
# Tool Usage: Connects directly with external systems like APIs, databases, and software to execute work (e.g., sending emails or updating a CRM)

# %%
"Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action."
# Out:
# 'Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action.'

# %%
"Agentic AI represents a shift in artificial intelligence from systems that merely generate content to systems that can take action.".split(' ')
# Out:
# ['Agentic',
#  'AI',
#  'represents',
#  'a',
#  'shift',
#  'in',
#  'artificial',
#  'intelligence',
#  'from',
#  'systems',
#  'that',
#  'merely',
#  'generate',
#  'content',
#  'to',
#  'systems',
#  'that',
#  'can',
#  'take',
#  'action.']

# %%
f.seek(0)
# Out:
# 0

# %%
l = []
for line in f.readlines():
    l.append(line.split(' '))

# %%
l
# Out:
# [['Agentic',
#   'AI',
#   'represents',
#   'a',
#   'shift',
#   'in',
#   'artificial',
#   'intelligence',
#   'from',
#   'systems',
#   'that',
#   'merely',
#   'generate',
#   'content',
#   'to',
#   'systems',
#   'that',
#   'can',
#   'take',
#   'action.',
#   'While',
#   'traditional',
#   'AI',
#   'is',
#   'reactive',
#   'and',
#   'follows',
#   'fixed',
#   'rules,',
#   'Agentic',
#   'AI',
#   'is',
#   'proactive',
#   'and',
#   'can',
#   'accomplish',
#   'complex',
#   'goals',
#   'with',
#   'minimal',
#   'human',
#   'intervention.',
#   '\n'],
#  ['IBM\n'],
#  ['IBM\n'],
#  ['', '+2\n'],
#  ['Key', 'Characteristics\n'],
#  ['Autonomy:',
#   'Operates',
#   'independently',
#   'without',
#   'needing',
#   'step-by-step',
#   'human',
#   'guidance.\n'],
#  ['Goal-Orientation:',
#   'Reasons',
#   'through',
#   'high-level',
#   'objectives,',
#   'breaking',
#   'them',
#   'down',
#   'into',
#   'multi-step',
#   'plans.\n'],
#  ['Adaptability:',
# ...

# %%
f.seek(0)
# Out:
# 0

# %%
l2 = []

# %%
for char in f.readline():
    l2.append(char)

# %%
l2
# Out:
# ['A',
#  'g',
#  'e',
#  'n',
#  't',
#  'i',
#  'c',
#  ' ',
#  'A',
#  'I',
#  ' ',
#  'r',
#  'e',
#  'p',
#  'r',
#  'e',
#  's',
#  'e',
#  'n',
#  't',
#  's',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'h',
#  'i',
#  'f',
#  't',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  'a',
#  'r',
#  't',
#  'i',
#  'f',
#  'i',
#  'c',
#  'i',
#  'a',
#  'l',
#  ' ',
#  'i',
#  'n',
#  't',
#  'e',
#  'l',
#  'l',
#  'i',
#  'g',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'f',
#  'r',
#  'o',
#  'm',
#  ' ',
#  's',
#  'y',
#  's',
#  't',
#  'e',
#  'm',
#  's',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'm',
#  'e',
#  'r',
#  'e',
#  'l',
#  'y',
#  ' ',
#  'g',
#  'e',
#  'n',
#  'e',
#  'r',
#  'a',
#  't',
#  'e',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'e',
#  'n',
#  't',
#  ' ',
#  't',
#  'o',
#  ' ',
#  's',
#  'y',
#  's',
#  't',
#  'e',
#  'm',
#  's',
#  ' ',
#  't',
#  'h',
#  'a',
#  't',
#  ' ',
#  'c',
#  'a',
#  'n',
#  ' ',
#  't',
#  'a',
#  'k',
#  'e',
#  ' ',
#  'a',
# ...

# %% [raw]
# # Paragraph
# goal : [a,e,i,o,u']
# print()

# %%
f.close()

# %%
# Overwrite

# %%
f = open('intro.txt', 'r+')

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.This is my updated intro'

# %%
f.write('This is my new text')
# Out:
# 19

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Hello my name is xyz. I have did may batchelors in xyz field.This is my updated introThis is my new text'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('field')
# Out:
# 5

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'field my name is xyz. I have did may batchelors in xyz field.This is my updated introThis is my new text'

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('Welcome to the world of AI')
# Out:
# 26

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'Welcome to the world of AIve did may batchelors in xyz field.This is my updated introThis is my new text'

# %%
f.close()

# %%
f = open('base.py', 'w')

# %%
f.write("""# This is base file of functions
def square(a):
    return a*a """)
# Out:
# 63

# %%
f.close()

# %%
f = open('base.py', 'r+')

# %%
f.read()
# Out:
# '# This is base file of functions\ndef square(a):\n    return a*a '

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['# This is base file of functions\n', 'def square(a):\n', '    return a*a ']

# %%
from base import square

# %%
square(5)
# Out:
# 25

# %%
#
