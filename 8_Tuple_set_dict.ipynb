# %%
# Tuple

# %%
t = (3,7.7,True,'Hello')

# %%
t
# Out:
# (3, 7.7, True, 'Hello')

# %%
type(t)
# Out:
# tuple

# %%
t[2]
# Out:
# True

# %%
t[1]
# Out:
# 7.7

# %%
t[3]
# Out:
# 'Hello'

# %%
t[0]
# Out:
# 3

# %%
t[0] = 300
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[0] = 300
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = (1,1,1,1,4,5,5,6,7,True,'Hello')

# %%
y
# Out:
# (1, 1, 1, 1, 4, 5, 5, 6, 7, True, 'Hello')

# %%
y.count(1)
# Out:
# 5

# %%
y.index(7)
# Out:
# 8

# %%
# Nested Tuple

# %%
u = (10,20,30,(50,60,70),90)

# %%
u
# Out:
# (10, 20, 30, (50, 60, 70), 90)

# %%
u[3]
# Out:
# (50, 60, 70)

# %%
u[3][0]
# Out:
# 50

# %%
o = (1,2,3,[1.5,2.5,3.5],9,60)

# %%
o
# Out:
# (1, 2, 3, [1.5, 2.5, 3.5], 9, 60)

# %% [markdown]
# # Typecasting

# %%
t
# Out:
# (3, 7.7, True, 'Hello')

# %%
type(t)
# Out:
# tuple

# %%
t = list(t)

# %%
t
# Out:
# [3, 7.7, True, 'Hello']

# %%
t.append(400)

# %%
t
# Out:
# [3, 7.7, True, 'Hello', 400]

# %%
t.remove('Hello')

# %%
t
# Out:
# [3, 7.7, True, 400]

# %%
t = tuple(t)

# %%
t
# Out:
# (3, 7.7, True, 400)

# %% [markdown]
# # Set

# %%
s = {1,2,3,4,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
type(s)
# Out:
# set

# %%
o = {1,1,1,'Hello', 'Hello'}

# %%
o
# Out:
# {1, 'Hello'}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s2.difference(s1)
# Out:
# {5, 6}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.remove(3)

# %%
s
# Out:
# {1, 2, 4, 5}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {2, 4, 5}

# %%
s.update('10')

# %%
s
# Out:
# {'0', '1', 2, 4, 5}

# %% [markdown]
# # Dictionary

# %%
d = {'a':1, 'age':20}

# %%
d
# Out:
# {'a': 1, 'age': 20}

# %%
type(d)
# Out:
# dict

# %%
students = {'Name':'Om', 'Class':10, 'Mobile':7584957859, 'City':'Solapur'}

# %%
students
# Out:
# {'Name': 'Om', 'Class': 10, 'Mobile': 7584957859, 'City': 'Solapur'}

# %%
data = {'names': ['Om', 'Sham', 'Ram', 'Shrusti', 'Sneha'], 'Age':[50,20,40,40,20] }

# %%
data
# Out:
# {'names': ['Om', 'Sham', 'Ram', 'Shrusti', 'Sneha'],
#  'Age': [50, 20, 40, 40, 20]}

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#      names  Age
# 0       Om   50
# 1     Sham   20
# 2      Ram   40
# 3  Shrusti   40
# 4    Sneha   20

# %%
d
# Out:
# {'a': 1, 'age': 20}
