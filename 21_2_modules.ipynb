# %%
summation(3,24,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 summation(3,24,2)
#
# NameError: name 'summation' is not defined

# %%
from imp_functions import summation

# %%
summation(3,5,6,7)
# Out:
# 21

# %%
import imp_functions

# %%
imp_functions.div(4,6)
# Out:
# 0.6666666666666666

# %%
imp_functions.multiply(4,3)
# Out:
# 12

# %%
imp_functions.summation(5,3,6,4)
# Out:
# 18

# %%
import imp_functions as gemini

# %%
gemini.div(23,5)
# Out:
# 4.6

# %%
import numpy as np

# %%
np.sum([4,6,4,2])
# Out:
# 16

# %%
import project

# %%
p
