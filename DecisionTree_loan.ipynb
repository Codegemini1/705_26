# %%
import pandas as pd

# %%
df = pd.read_csv('loan_approval_dataset.csv')

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df[' education'].unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
edu_map = {' Graduate':1,' Not Graduate':0 }

# %%
df[' education'] = df[' education'].map(edu_map)

# %%
df['education'] = df[' education']

# %%
df[' self_employed'].unique()
# Out:
# array([' No', ' Yes'], dtype=object)

# %%
self_map = {' No':0,' Yes':1 }

# %%
df[' self_employed'] = df[' self_employed'].map(self_map)

# %%
df['self_employed'] = df[' self_employed']

# %%
df[' loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
status_map = {' Approved':1,' Rejected':0 }

# %%
df[' loan_status'] = df[' loan_status'].map(status_map)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           1               0        9600000
# 1        2                  0           0               1        4100000
# 2        3                  3           1               0        9100000
# 3        4                  3           1               0        8200000
# 4        5                  5           0               1        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#     loan_status  education  self_employed
# 0             1          1              0
# 1             0          0              1
# 2             0          1              0
# 3             0          1              0
# 4             0          0              1

# %%
df.drop(columns=[' education', ' self_employed'],  inplace=True)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 0        1                  2        9600000      29900000          12
# 1        2                  0        4100000      12200000           8
# 2        3                  3        9100000      29700000          20
# 3        4                  3        8200000      30700000           8
# 4        5                  5        9800000      24200000          20
#
#     cibil_score   residential_assets_value   commercial_assets_value  \
# 0           778                    2400000                  17600000
# 1           417                    2700000                   2200000
# 2           506                    7100000                   4500000
# 3           467                   18200000                   3300000
# 4           382                   12400000                   8200000
#
#     luxury_assets_value   bank_asset_value   loan_status  education  \
# 0              22700000            8000000             1          1
# 1               8800000            3300000             0          0
# 2              33300000           12800000             0          1
# 3              23300000            7900000             0          1
# 4              29400000            5000000             0          0
#
#    self_employed
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1

# %%
df.drop('loan_id', axis=1, inplace=True)

# %%
df.corr()
# Out:
#                             no_of_dependents   income_annum   loan_amount  \
#  no_of_dependents                   1.000000       0.007266     -0.003366
#  income_annum                       0.007266       1.000000      0.927470
#  loan_amount                       -0.003366       0.927470      1.000000
#  loan_term                         -0.020111       0.011488      0.008437
#  cibil_score                       -0.009998      -0.023034     -0.017035
#  residential_assets_value           0.007376       0.636841      0.594596
#  commercial_assets_value           -0.001531       0.640328      0.603188
#  luxury_assets_value                0.002817       0.929145      0.860914
#  bank_asset_value                   0.011163       0.851093      0.788122
#  loan_status                       -0.018114      -0.015189      0.016150
# education                           0.002697       0.011625      0.010631
# self_employed                       0.000765       0.002368      0.001450
#
#                             loan_term   cibil_score  \
#  no_of_dependents           -0.020111     -0.009998
#  income_annum                0.011488     -0.023034
#  loan_amount                 0.008437     -0.017035
#  loan_term                   1.000000      0.007810
#  cibil_score                 0.007810      1.000000
#  residential_assets_value    0.008016     -0.019947
#  commercial_assets_value    -0.005478     -0.003769
#  luxury_assets_value         0.012490     -0.028618
#  bank_asset_value            0.017177     -0.015478
#  loan_status                -0.113036      0.770518
# education                   -0.008417     -0.004649
# self_employed                0.004107     -0.004866
#
#                             residential_assets_value  \
#  no_of_dependents                           0.007376
#  income_annum                               0.636841
#  loan_amount                                0.594596
#  loan_term                                  0.008016
#  cibil_score                               -0.019947
#  residential_assets_value                   1.000000
#  commercial_assets_value                    0.414786
#  luxury_assets_value                        0.590932
#  bank_asset_value                           0.527418
#  loan_status                               -0.014367
# education                                   0.010930
# self_employed                               0.006144
#
#                             commercial_assets_value   luxury_assets_value  \
#  no_of_dependents                         -0.001531              0.002817
#  income_annum                              0.640328              0.929145
#  loan_amount                               0.603188              0.860914
#  loan_term                                -0.005478              0.012490
#  cibil_score                              -0.003769             -0.028618
#  residential_assets_value                  0.414786              0.590932
#  commercial_assets_value                   1.000000              0.591128
#  luxury_assets_value                       0.591128              1.000000
#  bank_asset_value                          0.548576              0.788517
#  loan_status                               0.008246             -0.015465
# education                                 -0.006763              0.012471
# self_employed                             -0.017998              0.004413
#
#                             bank_asset_value   loan_status  education  \
#  no_of_dependents                   0.011163     -0.018114   0.002697
#  income_annum                       0.851093     -0.015189   0.011625
#  loan_amount                        0.788122      0.016150   0.010631
#  loan_term                          0.017177     -0.113036  -0.008417
#  cibil_score                       -0.015478      0.770518  -0.004649
#  residential_assets_value           0.527418     -0.014367   0.010930
#  commercial_assets_value            0.548576      0.008246  -0.006763
#  luxury_assets_value                0.788517     -0.015465   0.012471
#  bank_asset_value                   1.000000     -0.006778   0.009424
#  loan_status                       -0.006778      1.000000   0.004918
# education                           0.009424      0.004918   1.000000
# self_employed                      -0.000215      0.000345  -0.023224
#
#                            self_employed
#  no_of_dependents               0.000765
#  income_annum                   0.002368
#  loan_amount                    0.001450
#  loan_term                      0.004107
#  cibil_score                   -0.004866
#  residential_assets_value       0.006144
#  commercial_assets_value       -0.017998
#  luxury_assets_value            0.004413
#  bank_asset_value              -0.000215
#  loan_status                    0.000345
# education                      -0.023224
# self_employed                   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(' loan_status', axis=1)

# %%
X
# Out:
#        no_of_dependents   income_annum   loan_amount   loan_term  \
# 0                     2        9600000      29900000          12
# 1                     0        4100000      12200000           8
# 2                     3        9100000      29700000          20
# 3                     3        8200000      30700000           8
# 4                     5        9800000      24200000          20
# ...                 ...            ...           ...         ...
# 4264                  5        1000000       2300000          12
# 4265                  0        3300000      11300000          20
# 4266                  2        6500000      23900000          18
# 4267                  1        4100000      12800000           8
# 4268                  1        9200000      29700000          10
#
#        cibil_score   residential_assets_value   commercial_assets_value  \
# 0              778                    2400000                  17600000
# 1              417                    2700000                   2200000
# 2              506                    7100000                   4500000
# 3              467                   18200000                   3300000
# 4              382                   12400000                   8200000
# ...            ...                        ...                       ...
# 4264           317                    2800000                    500000
# 4265           559                    4200000                   2900000
# 4266           457                    1200000                  12400000
# 4267           780                    8200000                    700000
# 4268           607                   17800000                  11800000
#
#        luxury_assets_value   bank_asset_value  education  self_employed
# 0                 22700000            8000000          1              0
# 1                  8800000            3300000          0              1
# 2                 33300000           12800000          1              0
# 3                 23300000            7900000          1              0
# 4                 29400000            5000000          0              1
# ...                    ...                ...        ...            ...
# 4264               3300000             800000          1              1
# 4265              11000000            1900000          0              1
# 4266              18100000            7300000          0              0
# 4267              14100000            5800000          0              0
# 4268              35700000           12000000          1              0
#
# [4269 rows x 11 columns]

# %%
y = df[' loan_status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=40)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, classification_report, confusion_matrix

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[280,  36],
#        [ 35, 503]], dtype=int64)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9168618266978923

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       316
#            1       0.93      0.93      0.93       538
#
#     accuracy                           0.92       854
#    macro avg       0.91      0.91      0.91       854
# weighted avg       0.92      0.92      0.92       854

# %%
df.rename(columns={' income_annum': 'income_annum'})
# Out:
#        no_of_dependents  income_annum   loan_amount   loan_term   cibil_score  \
# 0                     2       9600000      29900000          12           778
# 1                     0       4100000      12200000           8           417
# 2                     3       9100000      29700000          20           506
# 3                     3       8200000      30700000           8           467
# 4                     5       9800000      24200000          20           382
# ...                 ...           ...           ...         ...           ...
# 4264                  5       1000000       2300000          12           317
# 4265                  0       3300000      11300000          20           559
# 4266                  2       6500000      23900000          18           457
# 4267                  1       4100000      12800000           8           780
# 4268                  1       9200000      29700000          10           607
#
#        residential_assets_value   commercial_assets_value  \
# 0                       2400000                  17600000
# 1                       2700000                   2200000
# 2                       7100000                   4500000
# 3                      18200000                   3300000
# 4                      12400000                   8200000
# ...                         ...                       ...
# 4264                    2800000                    500000
# 4265                    4200000                   2900000
# 4266                    1200000                  12400000
# 4267                    8200000                    700000
# 4268                   17800000                  11800000
#
#        luxury_assets_value   bank_asset_value   loan_status  education  \
# 0                 22700000            8000000             1          1
# 1                  8800000            3300000             0          0
# 2                 33300000           12800000             0          1
# 3                 23300000            7900000             0          1
# 4                 29400000            5000000             0          0
# ...                    ...                ...           ...        ...
# 4264               3300000             800000             0          1
# 4265              11000000            1900000             1          0
# 4266              18100000            7300000             0          0
# 4267              14100000            5800000             1          0
# 4268              35700000           12000000             1          1
#
#       self_employed
# 0                 0
# 1                 1
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 4264              1
# 4265              1
# 4266              0
# 4267              0
# 4268              0
#
# [4269 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
model = DecisionTreeClassifier(criterion='gini',random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9754098360655737

# %%
df.columns
# Out:
# Index([' no_of_dependents', ' income_annum', ' loan_amount', ' loan_term',
#        ' cibil_score', ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status',
#        'education', 'self_employed'],
#       dtype='object')

# %%
import numpy as np

# %%
plt.figure(figsize=(18,10))
plot_tree(
    model,
    feature_names= X.columns,
    class_names= model.classes_.astype(str),
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()
